# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')  # For latest NLTK versions
# Out:
# [nltk_data] Downloading package punkt to C:\Users\PARAM
# [nltk_data]     790\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Zip Slip blocked: punkt/
# [nltk_data] Downloading package punkt_tab to C:\Users\PARAM
# [nltk_data]     790\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# [nltk_data] Zip Slip blocked: punkt_tab/
# False

# %%
corpus = """In the fast-paced world of Python and Salesforce development, continuous learning fuels innovation. 
Dive into virtual environments, master Apex triggers, and optimize YouTube content—your toolkit for success
in Bangalore's tech scene grows stronger with every line of code."""

print(corpus)
# Out:
# In the fast-paced world of Python and Salesforce development, continuous learning fuels innovation.
# Dive into virtual environments, master Apex triggers, and optimize YouTube content—your toolkit for success
# in Bangalore's tech scene grows stronger with every line of code.

# %%
## Tokenization (Sentence 2 Word Tokenization  )
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
sent_tokenize(corpus)
# Out:
# ['In the fast-paced world of Python and Salesforce development, continuous learning fuels innovation.',
#  "Dive into virtual environments, master Apex triggers, and optimize YouTube content—your toolkit for success\nin Bangalore's tech scene grows stronger with every line of code."]
