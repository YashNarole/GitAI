# %%
# Out:
# ...
# 🎯 BAG OF WORDS RESULTS
# ...
# ✅ Shape: (8, 2)
# ✅ First 5 rows:
#    nan                                              label
# 0    1  ham,Go until jurong point, crazy.. Available o...
# 1    1                  ham,Ok lar... Joking wif u oni...
# 2    1  spam,Congratulations! You have won a free entr...
# 3    1  ham,U dun say so early hor... U c already then...
# 4    1  ham,Nah I don't think he goes to usf, he lives...
#
# ✅ Top 10 words:
# nan    8
# dtype: int64
#
# ✅ Sample SMS #1: nan    1
# Name: 0, dtype: int64
#
# ✅ Saved: bow.csv
# 🎉 DONE!
#
# 🎯 BOW VECTORS:
# Shape: (8, 1)
#
# First 5 SMS vectors (first 10 words):
# [[1]
#  [1]
#  [1]
#  [1]
#  [1]]
#
# First SMS full vector sample:
# Words used in SMS #1: nan    1
# Name: 0, dtype: int64
#
# Vocabulary sample: ['nan']
# [nltk_data] Downloading package stopwords to C:\Users\PARAM
# [nltk_data]     790\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
