# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\PARAM
# [nltk_data]     790\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package omw-1.4 to C:\Users\PARAM
# [nltk_data]     790\AppData\Roaming\nltk_data...
